# %% [markdown]
# Copyright **`(c)`** 2025 Giovanni Squillero `<giovanni.squillero@polito.it>`
# [`https://github.com/squillero/computational-intelligence`](https://github.com/squillero/computational-intelligence)
# Free under certain conditions — see the [`license`](https://github.com/squillero/computational-intelligence/blob/master/LICENSE.md) for details.

# %%
from itertools import product
import numpy as np
import networkx as nx
import heapq
import random
import time
from typing import List, Tuple, Optional, Dict, Any
import pandas as pd
import warnings

# Suppress NetworkX warnings about Bellman-Ford on large graphs
warnings.filterwarnings("ignore", category=UserWarning) 

# --- 1. PROBLEM GENERATOR ---

def create_problem(
    size: int,
    *,
    density: float = 1.0,
    negative_values: bool = False,
    noise_level: float = 0.0,
    seed: int = 42,
) -> Tuple[np.ndarray, np.ndarray]:
    """Returns cost matrix (problem) and city coordinates (city_coords)."""
    rng = np.random.default_rng(seed)
    city_coords = rng.random(size=(size, 2))
    problem = rng.random((size, size))
    
    if negative_values:
        # Scale values to range [-1, 1]
        problem = problem * 2 - 1
        
    problem *= noise_level
    
    for a, b in product(range(size), repeat=2):
        if rng.random() < density:
            # Calculate Euclidean distance
            dx = city_coords[a, 0] - city_coords[b, 0]
            dy = city_coords[a, 1] - city_coords[b, 1]
            dist = np.sqrt(dx * dx + dy * dy)
            problem[a, b] += dist
        else:
            problem[a, b] = np.inf # No edge

    np.fill_diagonal(problem, 0.0)
    # Scale costs to be larger integers (consistent with typical graph problems)
    return (problem * 1_000).round(), city_coords


# --- 2. BASELINE ALGORITHM (Bellman-Ford) ---

def matrix_to_graph(problem: np.ndarray) -> nx.DiGraph:
    """Convert a problem matrix to a directed NetworkX graph."""
    masked = np.ma.masked_array(problem, mask=np.isinf(problem))
    G = nx.from_numpy_array(masked, create_using=nx.DiGraph)
    return G

def bellman_ford_path(problem: np.ndarray, s: int, d: int) -> Tuple[Optional[List[int]], float]:
    """Baseline shortest path using NetworkX Bellman-Ford."""
    G = matrix_to_graph(problem)
    try:
        path = nx.bellman_ford_path(G, s, d, weight="weight")
        cost = nx.path_weight(G, path, weight="weight")
    except nx.NetworkXNoPath:
        path = None
        cost = np.inf
    except nx.NetworkXUnbounded:
        path = None
        cost = -np.inf # Negative cycle detected
    return path, cost


# --- 3. A* HEURISTIC & SEARCH ALGORITHM ---

def matrix_to_adj(problem: np.ndarray) -> List[List[Tuple[int, float]]]:
    """Convert a problem matrix to adjacency lists for heap-based A*."""
    n = problem.shape[0]
    adj = [[] for _ in range(n)]
    for u in range(n):
        for v in range(n):
            w = problem[u, v]
            if np.isfinite(w) and u != v:
                adj[u].append((v, float(w)))
    return adj

def euclidean_distance_heuristic(u: int, d: int, city_coords: np.ndarray) -> float:
    """Admissible heuristic: straight-line distance (h(n))."""
    pos_u = city_coords[u]
    pos_d = city_coords[d]
    return np.linalg.norm(pos_u - pos_d) * 1_000

def astar(problem: np.ndarray, s: int, d: int, city_coords: np.ndarray) -> Tuple[Optional[List[int]], float]:
    """
    A* search implementation using the Euclidean distance heuristic.
    Returns: (path, cost)
    """
    n = problem.shape[0]
    adj = matrix_to_adj(problem)

    def h(u: int) -> float:
        return euclidean_distance_heuristic(u, d, city_coords)

    # g[n] = cost from start to n
    g = [np.inf] * n
    g[s] = 0.0
    parent = [-1] * n
    # Heap stores (f = g + h, node)
    heap = [(h(s), s)] 

    while heap:
        f_u, u = heapq.heappop(heap)

        # Check for outdated entry due to path relaxation
        if f_u > g[u] + h(u) + 1e-6:
            continue
        
        if u == d:
            break

        for v, w in adj[u]:
            tentative_g = g[u] + w
            if tentative_g < g[v]:
                g[v] = tentative_g
                parent[v] = u
                f_v = tentative_g + h(v)
                heapq.heappush(heap, (f_v, v))

    if not np.isfinite(g[d]):
        return None, np.inf

    # Reconstruct path
    path = []
    cur = d
    while cur != -1:
        path.append(cur)
        if cur == s: break 
        cur = parent[cur]
    path.reverse()
    
    return path, g[d]


# --- 4. MAIN EXECUTION LOOP ---

# Parameters to test
sizes = [10,20, 100, 500,1000]
densities = [0.2,0.5, 0.8,1.0]
noise_levels = [0.0,0.1, 0.5,0.8]
neg_flags = [False, True]

# Only ONE sample per combination
num_pairs_per_problem = 1 
rng = np.random.default_rng(0) 

records: List[Dict[str, Any]] = []
scenario_counter = 1

for negative_values in neg_flags:
    for size in sizes:
        for density in densities:
            for noise_level in noise_levels:
                
                print(f"\n--- Scenario {scenario_counter} (Size: {size}, Density: {density}, Neg: {negative_values}) ---")
                
                problem, city_coords = create_problem(
                    size=size,
                    density=density,
                    noise_level=noise_level,
                    negative_values=negative_values,
                    seed=scenario_counter,
                )

                n = problem.shape[0]
                tried_pairs = 0
                s, d = -1, -1 # Initialize start/destination
                bf_cost = np.nan
                bf_path = None

                # Find a single valid (s, d) pair with a finite cost path
                while tried_pairs < num_pairs_per_problem * 10: 
                    tried_pairs += 1
                    s = int(rng.integers(0, n))
                    d = int(rng.integers(0, n))
                    if s == d: continue

                    bf_path_temp, bf_cost_temp = bellman_ford_path(problem, s, d)
                    
                    if np.isfinite(bf_cost_temp):
                        bf_path, bf_cost = bf_path_temp, bf_cost_temp
                        break
                else:
                    print("  Path sampling failed for this configuration (No finite path found).")
                    scenario_counter += 1
                    continue
                
                # --- Execute the comparison on the single valid path ---
                
                # Bellman-Ford Execution (Time)
                bf_time_start = time.perf_counter()
                bellman_ford_path(problem, s, d)
                bf_time = time.perf_counter() - bf_time_start
                bf_path_str = str(bf_path) if bf_path is not None else 'None'

                records.append({
                    "size": size, "density": density, "noise_level": noise_level, 
                    "negative_values": negative_values, "s": s, "d": d,
                    "algo": "BF", "cost": bf_cost, "time": bf_time, "path": bf_path_str,
                })
                print(f"  BF Result | Cost: {bf_cost:.2f} | Time: {bf_time:.4f}s | Path: {bf_path_str}")


                # A* Search Execution
                t0 = time.perf_counter()
                a_path, a_cost = astar(problem, s, d, city_coords)
                t1 = time.perf_counter()
                a_time = t1 - t0
                a_path_str = str(a_path) if a_path is not None else 'None'
                
                records.append({
                    "size": size, "density": density, "noise_level": noise_level, 
                    "negative_values": negative_values, "s": s, "d": d,
                    "algo": "A*", "cost": a_cost, "time": a_time, "path": a_path_str,
                })
                print(f"  A* Result | Cost: {a_cost:.2f} | Time: {a_time:.4f}s | Path: {a_path_str}")

                scenario_counter += 1


# 5. FINAL SUMMARY AND OUTPUT
df = pd.DataFrame(records)

# Filter for successful runs and algorithms
df_success = df[df['algo'].isin(['BF', 'A*'])].copy()

# Pivot table for final summary
summary = df_success.pivot_table(
    index=["size", "density", "noise_level", "negative_values", "s", "d"],
    columns="algo",
    values=["cost", "time", "path"],
    aggfunc='first'
)

# Flatten columns
summary.columns = [f'{col[0]}_{col[1]}' for col in summary.columns]
summary.reset_index(inplace=True)

# Rename columns for clear output
summary.rename(columns={
    'cost_BF': 'BF Cost', 'time_BF': 'BF Time (s)', 'path_BF': 'BF Path',
    'cost_A*': 'A* Cost', 'time_A*': 'A* Time (s)', 'path_A*': 'A* Path',
    's': 'Start', 'd': 'Goal'
}, inplace=True)

# Select columns for the final output (excluding error)
final_cols = [
    'size', 'density', 'noise_level', 'negative_values', 'Start', 'Goal', 
    'BF Cost', 'A* Cost', 'BF Time (s)', 'A* Time (s)', 'BF Path', 'A* Path'
]

summary = summary[final_cols]

# Export to CSV
summary.to_csv("shortest_path_comparison_summary.csv", index=False)

print(f"\n{'='*150}")
print("Final Summary: Bellman-Ford (BF) vs. A* (One Sample Per Case)")
print(f"{'='*150}")

# Print as Markdown
print(summary.to_markdown(index=False, floatfmt='.2f'))
print("\n---")
print("Data saved to shortest_path_comparison_summary.csv.")
# Out:
# --- Scenario 1 (Size: 10, Density: 0.2, Neg: False) ---
#   BF Result | Cost: 492.00 | Time: 0.0002s | Path: [5, 6]
#   A* Result | Cost: 492.00 | Time: 0.0002s | Path: [5, 6]
#
# --- Scenario 2 (Size: 10, Density: 0.2, Neg: False) ---
#   BF Result | Cost: 1519.00 | Time: 0.0002s | Path: [9, 8, 6, 7]
#   A* Result | Cost: 1519.00 | Time: 0.0003s | Path: [9, 8, 6, 7]
#
# --- Scenario 3 (Size: 10, Density: 0.2, Neg: False) ---
#   BF Result | Cost: 2210.00 | Time: 0.0002s | Path: [2, 6, 1, 8]
#   A* Result | Cost: 2210.00 | Time: 0.0002s | Path: [2, 6, 1, 8]
#
# --- Scenario 4 (Size: 10, Density: 0.2, Neg: False) ---
#   BF Result | Cost: 1770.00 | Time: 0.0002s | Path: [3, 5, 6, 8]
#   A* Result | Cost: 1770.00 | Time: 0.0002s | Path: [3, 5, 6, 8]
#
# --- Scenario 5 (Size: 10, Density: 0.5, Neg: False) ---
#   BF Result | Cost: 886.00 | Time: 0.0003s | Path: [5, 8, 0]
#   A* Result | Cost: 886.00 | Time: 0.0003s | Path: [5, 8, 0]
#
# --- Scenario 6 (Size: 10, Density: 0.5, Neg: False) ---
#   BF Result | Cost: 989.00 | Time: 0.0003s | Path: [8, 3, 0, 1]
#   A* Result | Cost: 989.00 | Time: 0.0003s | Path: [8, 3, 0, 1]
#
# --- Scenario 7 (Size: 10, Density: 0.5, Neg: False) ---
#   BF Result | Cost: 699.00 | Time: 0.0003s | Path: [0, 8]
#   A* Result | Cost: 699.00 | Time: 0.0002s | Path: [0, 8]
#
# --- Scenario 8 (Size: 10, Density: 0.5, Neg: False) ---
#   BF Result | Cost: 880.00 | Time: 0.0003s | Path: [0, 5]
#   A* Result | Cost: 880.00 | Time: 0.0003s | Path: [0, 5]
#
# --- Scenario 9 (Size: 10, Density: 0.8, Neg: False) ---
#   BF Result | Cost: 737.00 | Time: 0.0004s | Path: [0, 1, 2]
#   A* Result | Cost: 737.00 | Time: 0.0003s | Path: [0, 1, 2]
#
# --- Scenario 10 (Size: 10, Density: 0.8, Neg: False) ---
#   BF Result | Cost: 945.00 | Time: 0.0004s | Path: [4, 0]
#   A* Result | Cost: 945.00 | Time: 0.0003s | Path: [4, 0]
#
# --- Scenario 11 (Size: 10, Density: 0.8, Neg: False) ---
#   BF Result | Cost: 769.00 | Time: 0.0004s | Path: [0, 1]
#   A* Result | Cost: 769.00 | Time: 0.0002s | Path: [0, 1]
#
# --- Scenario 12 (Size: 10, Density: 0.8, Neg: False) ---
#   BF Result | Cost: 1223.00 | Time: 0.0004s | Path: [0, 6]
#   A* Result | Cost: 1223.00 | Time: 0.0003s | Path: [0, 6]
#
# --- Scenario 13 (Size: 10, Density: 1.0, Neg: False) ---
#   BF Result | Cost: 427.00 | Time: 0.0005s | Path: [5, 6]
#   A* Result | Cost: 427.00 | Time: 0.0003s | Path: [5, 6]
#
# --- Scenario 14 (Size: 10, Density: 1.0, Neg: False) ---
#   BF Result | Cost: 253.00 | Time: 0.0005s | Path: [2, 6]
#   A* Result | Cost: 253.00 | Time: 0.0003s | Path: [2, 6]
#
# --- Scenario 15 (Size: 10, Density: 1.0, Neg: False) ---
#   BF Result | Cost: 1223.00 | Time: 0.0005s | Path: [7, 3]
#   A* Result | Cost: 1223.00 | Time: 0.0002s | Path: [7, 3]
#
# --- Scenario 16 (Size: 10, Density: 1.0, Neg: False) ---
#   BF Result | Cost: 752.00 | Time: 0.0005s | Path: [4, 6, 9]
#   A* Result | Cost: 752.00 | Time: 0.0003s | Path: [4, 6, 9]
#
# --- Scenario 17 (Size: 20, Density: 0.2, Neg: False) ---
#   BF Result | Cost: 251.00 | Time: 0.0005s | Path: [16, 19]
#   A* Result | Cost: 251.00 | Time: 0.0005s | Path: [16, 19]
#
# --- Scenario 18 (Size: 20, Density: 0.2, Neg: False) ---
#   BF Result | Cost: 1224.00 | Time: 0.0005s | Path: [7, 5, 13]
#   A* Result | Cost: 1224.00 | Time: 0.0006s | Path: [7, 5, 13]
#
# --- Scenario 19 (Size: 20, Density: 0.2, Neg: False) ---
#   BF Result | Cost: 1061.00 | Time: 0.0004s | Path: [19, 13]
#   A* Result | Cost: 1061.00 | Time: 0.0005s | Path: [19, 13]
#
# --- Scenario 20 (Size: 20, Density: 0.2, Neg: False) ---
#   BF Result | Cost: 969.00 | Time: 0.0005s | Path: [16, 5, 13]
#   A* Result | Cost: 969.00 | Time: 0.0005s | Path: [16, 5, 13]
#
# --- Scenario 21 (Size: 20, Density: 0.5, Neg: False) ---
#   BF Result | Cost: 661.00 | Time: 0.0008s | Path: [14, 7]
#   A* Result | Cost: 661.00 | Time: 0.0005s | Path: [14, 7]
#
# --- Scenario 22 (Size: 20, Density: 0.5, Neg: False) ---
#   BF Result | Cost: 1226.00 | Time: 0.0008s | Path: [17, 19, 2]
#   A* Result | Cost: 1226.00 | Time: 0.0006s | Path: [17, 19, 2]
#
# --- Scenario 23 (Size: 20, Density: 0.5, Neg: False) ---
#   BF Result | Cost: 484.00 | Time: 0.0008s | Path: [11, 2, 14]
#   A* Result | Cost: 484.00 | Time: 0.0006s | Path: [11, 2, 14]
#
# --- Scenario 24 (Size: 20, Density: 0.5, Neg: False) ---
#   BF Result | Cost: 937.00 | Time: 0.0008s | Path: [16, 0, 10]
#   A* Result | Cost: 937.00 | Time: 0.0006s | Path: [16, 0, 10]
#
# --- Scenario 25 (Size: 20, Density: 0.8, Neg: False) ---
#   BF Result | Cost: 320.00 | Time: 0.0013s | Path: [7, 6]
#   A* Result | Cost: 320.00 | Time: 0.0006s | Path: [7, 6]
#
# --- Scenario 26 (Size: 20, Density: 0.8, Neg: False) ---
#   BF Result | Cost: 707.00 | Time: 0.0012s | Path: [8, 11, 9]
#   A* Result | Cost: 707.00 | Time: 0.0006s | Path: [8, 11, 9]
#
# --- Scenario 27 (Size: 20, Density: 0.8, Neg: False) ---
#   BF Result | Cost: 657.00 | Time: 0.0012s | Path: [14, 16, 17]
#   A* Result | Cost: 657.00 | Time: 0.0006s | Path: [14, 16, 17]
#
# --- Scenario 28 (Size: 20, Density: 0.8, Neg: False) ---
#   BF Result | Cost: 785.00 | Time: 0.0012s | Path: [1, 7, 18]
#   A* Result | Cost: 785.00 | Time: 0.0007s | Path: [1, 7, 18]
#
# --- Scenario 29 (Size: 20, Density: 1.0, Neg: False) ---
#   BF Result | Cost: 340.00 | Time: 0.0014s | Path: [10, 7]
#   A* Result | Cost: 340.00 | Time: 0.0006s | Path: [10, 7]
#
# --- Scenario 30 (Size: 20, Density: 1.0, Neg: False) ---
#   BF Result | Cost: 839.00 | Time: 0.0014s | Path: [13, 11]
#   A* Result | Cost: 839.00 | Time: 0.0006s | Path: [13, 11]
#
# --- Scenario 31 (Size: 20, Density: 1.0, Neg: False) ---
#   BF Result | Cost: 893.00 | Time: 0.0014s | Path: [5, 6]
#   A* Result | Cost: 893.00 | Time: 0.0006s | Path: [5, 6]
#
# --- Scenario 32 (Size: 20, Density: 1.0, Neg: False) ---
#   BF Result | Cost: 245.00 | Time: 0.0013s | Path: [14, 11]
#   A* Result | Cost: 245.00 | Time: 0.0005s | Path: [14, 11]
#
# --- Scenario 33 (Size: 100, Density: 0.2, Neg: False) ---
#   BF Result | Cost: 885.00 | Time: 0.0062s | Path: [50, 63, 33]
#   A* Result | Cost: 885.00 | Time: 0.0083s | Path: [50, 63, 33]
#
# --- Scenario 34 (Size: 100, Density: 0.2, Neg: False) ---
#   BF Result | Cost: 671.00 | Time: 0.0067s | Path: [76, 29, 39]
#   A* Result | Cost: 671.00 | Time: 0.0082s | Path: [76, 29, 39]
#
# --- Scenario 35 (Size: 100, Density: 0.2, Neg: False) ---
#   BF Result | Cost: 1015.00 | Time: 0.0064s | Path: [32, 52, 89]
#   A* Result | Cost: 1015.00 | Time: 0.0083s | Path: [32, 52, 89]
#
# --- Scenario 36 (Size: 100, Density: 0.2, Neg: False) ---
#   BF Result | Cost: 1547.00 | Time: 0.0061s | Path: [26, 43, 40, 22]
#   A* Result | Cost: 1547.00 | Time: 0.0086s | Path: [26, 43, 40, 22]
#
# --- Scenario 37 (Size: 100, Density: 0.5, Neg: False) ---
#   BF Result | Cost: 373.00 | Time: 0.0154s | Path: [71, 82, 62]
#   A* Result | Cost: 373.00 | Time: 0.0092s | Path: [71, 82, 62]
#
# --- Scenario 38 (Size: 100, Density: 0.5, Neg: False) ---
#   BF Result | Cost: 325.00 | Time: 0.0156s | Path: [4, 7, 8]
#   A* Result | Cost: 325.00 | Time: 0.0094s | Path: [4, 7, 8]
#
# --- Scenario 39 (Size: 100, Density: 0.5, Neg: False) ---
#   BF Result | Cost: 680.00 | Time: 0.0152s | Path: [37, 4, 83]
#   A* Result | Cost: 680.00 | Time: 0.0091s | Path: [37, 4, 83]
#
# --- Scenario 40 (Size: 100, Density: 0.5, Neg: False) ---
#   BF Result | Cost: 1171.00 | Time: 0.0153s | Path: [40, 70, 78]
#   A* Result | Cost: 1171.00 | Time: 0.0092s | Path: [40, 70, 78]
#
# --- Scenario 41 (Size: 100, Density: 0.8, Neg: False) ---
#   BF Result | Cost: 1135.00 | Time: 0.0229s | Path: [31, 1, 23]
#   A* Result | Cost: 1135.00 | Time: 0.0093s | Path: [31, 96, 23]
#
# --- Scenario 42 (Size: 100, Density: 0.8, Neg: False) ---
#   BF Result | Cost: 955.00 | Time: 0.0238s | Path: [79, 23, 87]
#   A* Result | Cost: 955.00 | Time: 0.0096s | Path: [79, 23, 87]
#
# --- Scenario 43 (Size: 100, Density: 0.8, Neg: False) ---
#   BF Result | Cost: 1177.00 | Time: 0.0241s | Path: [7, 79, 5]
#   A* Result | Cost: 1177.00 | Time: 0.0098s | Path: [7, 79, 5]
#
# --- Scenario 44 (Size: 100, Density: 0.8, Neg: False) ---
#   BF Result | Cost: 1005.00 | Time: 0.0239s | Path: [67, 36, 31, 33]
#   A* Result | Cost: 1005.00 | Time: 0.0106s | Path: [67, 36, 31, 33]
#
# --- Scenario 45 (Size: 100, Density: 1.0, Neg: False) ---
#   BF Result | Cost: 481.00 | Time: 0.0284s | Path: [57, 15]
#   A* Result | Cost: 481.00 | Time: 0.0097s | Path: [57, 15]
#
# --- Scenario 46 (Size: 100, Density: 1.0, Neg: False) ---
#   BF Result | Cost: 379.00 | Time: 0.0295s | Path: [86, 45]
#   A* Result | Cost: 379.00 | Time: 0.0099s | Path: [86, 45]
#
# --- Scenario 47 (Size: 100, Density: 1.0, Neg: False) ---
#   BF Result | Cost: 858.00 | Time: 0.0309s | Path: [89, 45, 79]
#   A* Result | Cost: 858.00 | Time: 0.0105s | Path: [89, 45, 79]
#
# --- Scenario 48 (Size: 100, Density: 1.0, Neg: False) ---
#   BF Result | Cost: 865.00 | Time: 0.0318s | Path: [70, 35, 23]
#   A* Result | Cost: 865.00 | Time: 0.0112s | Path: [70, 35, 23]
#
# --- Scenario 49 (Size: 500, Density: 0.2, Neg: False) ---
#   BF Result | Cost: 792.00 | Time: 0.1655s | Path: [383, 180, 26]
#   A* Result | Cost: 792.00 | Time: 0.2206s | Path: [383, 180, 26]
#
# --- Scenario 50 (Size: 500, Density: 0.2, Neg: False) ---
#   BF Result | Cost: 565.00 | Time: 0.2210s | Path: [285, 352, 202]
#   A* Result | Cost: 565.00 | Time: 0.2450s | Path: [285, 352, 202]
#
# --- Scenario 51 (Size: 500, Density: 0.2, Neg: False) ---
#   BF Result | Cost: 1136.00 | Time: 0.1814s | Path: [498, 22, 188, 99]
#   A* Result | Cost: 1136.00 | Time: 0.2225s | Path: [498, 22, 188, 99]
#
# --- Scenario 52 (Size: 500, Density: 0.2, Neg: False) ---
#   BF Result | Cost: 977.00 | Time: 0.1730s | Path: [473, 133, 451, 45]
#   A* Result | Cost: 977.00 | Time: 0.2143s | Path: [473, 133, 451, 45]
#
# --- Scenario 53 (Size: 500, Density: 0.5, Neg: False) ---
#   BF Result | Cost: 696.00 | Time: 0.4214s | Path: [311, 141, 290]
#   A* Result | Cost: 696.00 | Time: 0.2535s | Path: [311, 141, 290]
#
# --- Scenario 54 (Size: 500, Density: 0.5, Neg: False) ---
#   BF Result | Cost: 908.00 | Time: 0.4551s | Path: [449, 221, 149]
#   A* Result | Cost: 908.00 | Time: 0.2232s | Path: [449, 221, 149]
#
# --- Scenario 55 (Size: 500, Density: 0.5, Neg: False) ---
#   BF Result | Cost: 570.00 | Time: 0.4313s | Path: [451, 205, 319, 335]
#   A* Result | Cost: 570.00 | Time: 0.3134s | Path: [451, 205, 319, 335]
#
# --- Scenario 56 (Size: 500, Density: 0.5, Neg: False) ---
#   BF Result | Cost: 850.00 | Time: 0.4824s | Path: [445, 287, 99]
#   A* Result | Cost: 850.00 | Time: 0.2750s | Path: [445, 287, 99]
#
# --- Scenario 57 (Size: 500, Density: 0.8, Neg: False) ---
#   BF Result | Cost: 220.00 | Time: 0.6678s | Path: [379, 471]
#   A* Result | Cost: 220.00 | Time: 0.2418s | Path: [379, 471]
#
# --- Scenario 58 (Size: 500, Density: 0.8, Neg: False) ---
#   BF Result | Cost: 609.00 | Time: 0.7259s | Path: [24, 182]
#   A* Result | Cost: 609.00 | Time: 0.2641s | Path: [24, 182]
#
# --- Scenario 59 (Size: 500, Density: 0.8, Neg: False) ---
#   BF Result | Cost: 939.00 | Time: 0.6975s | Path: [318, 144, 101, 52]
#   A* Result | Cost: 939.00 | Time: 0.2528s | Path: [318, 144, 101, 52]
#
# --- Scenario 60 (Size: 500, Density: 0.8, Neg: False) ---
#   BF Result | Cost: 951.00 | Time: 0.6869s | Path: [255, 419, 221, 314]
#   A* Result | Cost: 951.00 | Time: 0.2520s | Path: [255, 419, 221, 314]
#
# --- Scenario 61 (Size: 500, Density: 1.0, Neg: False) ---
#   BF Result | Cost: 741.00 | Time: 0.7897s | Path: [381, 382, 23, 82, 463]
#   A* Result | Cost: 742.00 | Time: 0.2476s | Path: [381, 463]
#
# --- Scenario 62 (Size: 500, Density: 1.0, Neg: False) ---
#   BF Result | Cost: 315.00 | Time: 0.8642s | Path: [204, 420, 192, 220]
#   A* Result | Cost: 315.00 | Time: 0.2503s | Path: [204, 420, 192, 220]
#
# --- Scenario 63 (Size: 500, Density: 1.0, Neg: False) ---
#   BF Result | Cost: 516.00 | Time: 0.9819s | Path: [237, 60, 345, 477]
#   A* Result | Cost: 516.00 | Time: 0.2563s | Path: [237, 60, 345, 477]
#
# --- Scenario 64 (Size: 500, Density: 1.0, Neg: False) ---
#   BF Result | Cost: 910.00 | Time: 0.9601s | Path: [97, 277, 70, 249]
#   A* Result | Cost: 910.00 | Time: 0.2516s | Path: [97, 277, 70, 249]
#
# --- Scenario 65 (Size: 1000, Density: 0.2, Neg: False) ---
#   BF Result | Cost: 455.00 | Time: 0.6929s | Path: [49, 425]
#   A* Result | Cost: 455.00 | Time: 0.9334s | Path: [49, 425]
#
# --- Scenario 66 (Size: 1000, Density: 0.2, Neg: False) ---
#   BF Result | Cost: 487.00 | Time: 0.6877s | Path: [945, 608, 730, 620]
#   A* Result | Cost: 487.00 | Time: 0.9460s | Path: [945, 608, 730, 620]
#
# --- Scenario 67 (Size: 1000, Density: 0.2, Neg: False) ---
#   BF Result | Cost: 508.00 | Time: 0.6926s | Path: [349, 995]
#   A* Result | Cost: 508.00 | Time: 0.8055s | Path: [349, 995]
#
# --- Scenario 68 (Size: 1000, Density: 0.2, Neg: False) ---
#   BF Result | Cost: 934.00 | Time: 0.8759s | Path: [603, 279, 155, 8, 948]
#   A* Result | Cost: 934.00 | Time: 0.9602s | Path: [603, 279, 155, 8, 948]
#
# --- Scenario 69 (Size: 1000, Density: 0.5, Neg: False) ---
#   BF Result | Cost: 857.00 | Time: 1.8064s | Path: [16, 242, 109, 460]
#   A* Result | Cost: 857.00 | Time: 0.8943s | Path: [16, 242, 109, 460]
#
# --- Scenario 70 (Size: 1000, Density: 0.5, Neg: False) ---
#   BF Result | Cost: 193.00 | Time: 1.7879s | Path: [834, 757]
#   A* Result | Cost: 193.00 | Time: 0.8660s | Path: [834, 757]
#
# --- Scenario 71 (Size: 1000, Density: 0.5, Neg: False) ---
#   BF Result | Cost: 657.00 | Time: 1.7294s | Path: [407, 949, 651, 497]
#   A* Result | Cost: 657.00 | Time: 0.8813s | Path: [407, 949, 651, 497]
#
# --- Scenario 72 (Size: 1000, Density: 0.5, Neg: False) ---
#   BF Result | Cost: 758.00 | Time: 1.7267s | Path: [420, 939, 907, 529]
#   A* Result | Cost: 758.00 | Time: 0.9371s | Path: [420, 939, 907, 529]
#
# --- Scenario 73 (Size: 1000, Density: 0.8, Neg: False) ---
#   BF Result | Cost: 578.00 | Time: 2.6632s | Path: [230, 89, 785]
#   A* Result | Cost: 578.00 | Time: 0.9201s | Path: [230, 89, 785]
#
# --- Scenario 74 (Size: 1000, Density: 0.8, Neg: False) ---
#   BF Result | Cost: 450.00 | Time: 2.9054s | Path: [77, 856, 414]
#   A* Result | Cost: 450.00 | Time: 0.9229s | Path: [77, 856, 414]
#
# --- Scenario 75 (Size: 1000, Density: 0.8, Neg: False) ---
#   BF Result | Cost: 412.00 | Time: 2.9376s | Path: [281, 289, 734]
#   A* Result | Cost: 412.00 | Time: 1.0834s | Path: [281, 289, 734]
#
# --- Scenario 76 (Size: 1000, Density: 0.8, Neg: False) ---
#   BF Result | Cost: 527.00 | Time: 2.9670s | Path: [749, 497, 711]
#   A* Result | Cost: 527.00 | Time: 1.0127s | Path: [749, 497, 711]
#
# --- Scenario 77 (Size: 1000, Density: 1.0, Neg: False) ---
#   BF Result | Cost: 783.00 | Time: 3.3407s | Path: [924, 511, 4, 932]
#   A* Result | Cost: 783.00 | Time: 1.0170s | Path: [924, 511, 4, 932]
#
# --- Scenario 78 (Size: 1000, Density: 1.0, Neg: False) ---
#   BF Result | Cost: 912.00 | Time: 3.9108s | Path: [184, 650, 114]
#   A* Result | Cost: 912.00 | Time: 1.1191s | Path: [184, 650, 114]
#
# --- Scenario 79 (Size: 1000, Density: 1.0, Neg: False) ---
#   BF Result | Cost: 640.00 | Time: 3.4796s | Path: [132, 551, 938, 729]
#   A* Result | Cost: 640.00 | Time: 0.9826s | Path: [132, 551, 938, 729]
#
# --- Scenario 80 (Size: 1000, Density: 1.0, Neg: False) ---
#   BF Result | Cost: 765.00 | Time: 3.5829s | Path: [970, 711, 784, 927]
#   A* Result | Cost: 765.00 | Time: 0.9785s | Path: [970, 711, 784, 927]
#
# --- Scenario 81 (Size: 10, Density: 0.2, Neg: True) ---
#   BF Result | Cost: 794.00 | Time: 0.0002s | Path: [6, 2, 9]
#   A* Result | Cost: 794.00 | Time: 0.0003s | Path: [6, 2, 9]
#
# --- Scenario 82 (Size: 10, Density: 0.2, Neg: True) ---
#   BF Result | Cost: 837.00 | Time: 0.0002s | Path: [8, 4, 0]
#   A* Result | Cost: 837.00 | Time: 0.0002s | Path: [8, 4, 0]
#
# --- Scenario 83 (Size: 10, Density: 0.2, Neg: True) ---
#   Path sampling failed for this configuration (No finite path found).
#
# --- Scenario 84 (Size: 10, Density: 0.2, Neg: True) ---
#   BF Result | Cost: 949.00 | Time: 0.0001s | Path: [8, 5, 0, 7]
#   A* Result | Cost: 949.00 | Time: 0.0002s | Path: [8, 5, 0, 7]
#
# --- Scenario 85 (Size: 10, Density: 0.5, Neg: True) ---
#   BF Result | Cost: 629.00 | Time: 0.0003s | Path: [1, 6]
#   A* Result | Cost: 629.00 | Time: 0.0002s | Path: [1, 6]
#
# --- Scenario 86 (Size: 10, Density: 0.5, Neg: True) ---
#   BF Result | Cost: 485.00 | Time: 0.0003s | Path: [5, 0]
#   A* Result | Cost: 485.00 | Time: 0.0002s | Path: [5, 0]
#
# --- Scenario 87 (Size: 10, Density: 0.5, Neg: True) ---
#   BF Result | Cost: 103.00 | Time: 0.0003s | Path: [9, 1, 2, 8, 7]
#   A* Result | Cost: 103.00 | Time: 0.0002s | Path: [9, 1, 2, 8, 7]
#
# --- Scenario 88 (Size: 10, Density: 0.5, Neg: True) ---
#   BF Result | Cost: 285.00 | Time: 0.0003s | Path: [3, 6, 7, 0]
#   A* Result | Cost: 299.00 | Time: 0.0002s | Path: [3, 0]
#
# --- Scenario 89 (Size: 10, Density: 0.8, Neg: True) ---
#   BF Result | Cost: 708.00 | Time: 0.0004s | Path: [0, 7]
#   A* Result | Cost: 708.00 | Time: 0.0002s | Path: [0, 7]
#
# --- Scenario 90 (Size: 10, Density: 0.8, Neg: True) ---
#   BF Result | Cost: 479.00 | Time: 0.0004s | Path: [1, 5]
#   A* Result | Cost: 479.00 | Time: 0.0002s | Path: [1, 5]
#
# --- Scenario 91 (Size: 10, Density: 0.8, Neg: True) ---
#   BF Result | Cost: 316.00 | Time: 0.0004s | Path: [8, 1, 9]
#   A* Result | Cost: 419.00 | Time: 0.0002s | Path: [8, 9]
#
# --- Scenario 92 (Size: 10, Density: 0.8, Neg: True) ---
#   Path sampling failed for this configuration (No finite path found).
#
# --- Scenario 93 (Size: 10, Density: 1.0, Neg: True) ---
#   BF Result | Cost: 899.00 | Time: 0.0004s | Path: [7, 2]
#   A* Result | Cost: 899.00 | Time: 0.0002s | Path: [7, 2]
#
# --- Scenario 94 (Size: 10, Density: 1.0, Neg: True) ---
#   BF Result | Cost: 643.00 | Time: 0.0004s | Path: [8, 5]
#   A* Result | Cost: 643.00 | Time: 0.0002s | Path: [8, 5]
#
# --- Scenario 95 (Size: 10, Density: 1.0, Neg: True) ---
#   Path sampling failed for this configuration (No finite path found).
#
# --- Scenario 96 (Size: 10, Density: 1.0, Neg: True) ---
#   Path sampling failed for this configuration (No finite path found).
#
# --- Scenario 97 (Size: 20, Density: 0.2, Neg: True) ---
#   BF Result | Cost: 1182.00 | Time: 0.0003s | Path: [2, 8, 7]
#   A* Result | Cost: 1182.00 | Time: 0.0004s | Path: [2, 8, 7]
#
# --- Scenario 98 (Size: 20, Density: 0.2, Neg: True) ---
#   BF Result | Cost: 37.00 | Time: 0.0003s | Path: [2, 1]
#   A* Result | Cost: 37.00 | Time: 0.0003s | Path: [2, 1]
#
# --- Scenario 99 (Size: 20, Density: 0.2, Neg: True) ---
#   BF Result | Cost: 649.00 | Time: 0.0003s | Path: [5, 10, 12, 18, 9, 13]
#   A* Result | Cost: 649.00 | Time: 0.0004s | Path: [5, 10, 12, 18, 9, 13]
#
# --- Scenario 100 (Size: 20, Density: 0.2, Neg: True) ---
#   Path sampling failed for this configuration (No finite path found).
#
# --- Scenario 101 (Size: 20, Density: 0.5, Neg: True) ---
#   BF Result | Cost: 433.00 | Time: 0.0006s | Path: [13, 15]
#   A* Result | Cost: 433.00 | Time: 0.0004s | Path: [13, 15]
#
# --- Scenario 102 (Size: 20, Density: 0.5, Neg: True) ---
#   BF Result | Cost: 633.00 | Time: 0.0006s | Path: [0, 6]
#   A* Result | Cost: 633.00 | Time: 0.0004s | Path: [0, 6]
#
# --- Scenario 103 (Size: 20, Density: 0.5, Neg: True) ---
#   Path sampling failed for this configuration (No finite path found).
#
# --- Scenario 104 (Size: 20, Density: 0.5, Neg: True) ---
#   Path sampling failed for this configuration (No finite path found).
#
# --- Scenario 105 (Size: 20, Density: 0.8, Neg: True) ---
#   BF Result | Cost: 421.00 | Time: 0.0009s | Path: [13, 7]
#   A* Result | Cost: 421.00 | Time: 0.0004s | Path: [13, 7]
#
# --- Scenario 106 (Size: 20, Density: 0.8, Neg: True) ---
#   Path sampling failed for this configuration (No finite path found).
#
# --- Scenario 107 (Size: 20, Density: 0.8, Neg: True) ---
#   Path sampling failed for this configuration (No finite path found).
#
# --- Scenario 108 (Size: 20, Density: 0.8, Neg: True) ---
#   Path sampling failed for this configuration (No finite path found).
#
# --- Scenario 109 (Size: 20, Density: 1.0, Neg: True) ---
#   BF Result | Cost: 370.00 | Time: 0.0011s | Path: [4, 9]
#   A* Result | Cost: 370.00 | Time: 0.0005s | Path: [4, 9]
#
# --- Scenario 110 (Size: 20, Density: 1.0, Neg: True) ---
#   Path sampling failed for this configuration (No finite path found).
#
# --- Scenario 111 (Size: 20, Density: 1.0, Neg: True) ---
#   Path sampling failed for this configuration (No finite path found).
#
# --- Scenario 112 (Size: 20, Density: 1.0, Neg: True) ---
#   Path sampling failed for this configuration (No finite path found).
#
# --- Scenario 113 (Size: 100, Density: 0.2, Neg: True) ---
#   BF Result | Cost: 743.00 | Time: 0.0063s | Path: [88, 53, 6]
#   A* Result | Cost: 743.00 | Time: 0.0084s | Path: [88, 53, 6]
#
# --- Scenario 114 (Size: 100, Density: 0.2, Neg: True) ---
#   Path sampling failed for this configuration (No finite path found).
#
# --- Scenario 115 (Size: 100, Density: 0.2, Neg: True) ---
#   Path sampling failed for this configuration (No finite path found).
#
# --- Scenario 116 (Size: 100, Density: 0.2, Neg: True) ---
#   Path sampling failed for this configuration (No finite path found).
#
# --- Scenario 117 (Size: 100, Density: 0.5, Neg: True) ---
#   BF Result | Cost: 518.00 | Time: 0.0151s | Path: [65, 37, 97]
#   A* Result | Cost: 518.00 | Time: 0.0089s | Path: [65, 37, 97]
#
# --- Scenario 118 (Size: 100, Density: 0.5, Neg: True) ---
#   Path sampling failed for this configuration (No finite path found).
#
# --- Scenario 119 (Size: 100, Density: 0.5, Neg: True) ---
#   Path sampling failed for this configuration (No finite path found).
#
# --- Scenario 120 (Size: 100, Density: 0.5, Neg: True) ---
#   Path sampling failed for this configuration (No finite path found).
#
# --- Scenario 121 (Size: 100, Density: 0.8, Neg: True) ---
#   BF Result | Cost: 402.00 | Time: 0.0244s | Path: [80, 17]
#   A* Result | Cost: 402.00 | Time: 0.0099s | Path: [80, 17]
#
# --- Scenario 122 (Size: 100, Density: 0.8, Neg: True) ---
#   Path sampling failed for this configuration (No finite path found).
#
# --- Scenario 123 (Size: 100, Density: 0.8, Neg: True) ---
#   Path sampling failed for this configuration (No finite path found).
#
# --- Scenario 124 (Size: 100, Density: 0.8, Neg: True) ---
#   Path sampling failed for this configuration (No finite path found).
#
# --- Scenario 125 (Size: 100, Density: 1.0, Neg: True) ---
#   BF Result | Cost: 442.00 | Time: 0.0334s | Path: [13, 50, 71]
#   A* Result | Cost: 442.00 | Time: 0.0100s | Path: [13, 50, 71]
#
# --- Scenario 126 (Size: 100, Density: 1.0, Neg: True) ---
#   Path sampling failed for this configuration (No finite path found).
#
# --- Scenario 127 (Size: 100, Density: 1.0, Neg: True) ---
#   Path sampling failed for this configuration (No finite path found).
#
# --- Scenario 128 (Size: 100, Density: 1.0, Neg: True) ---
#   Path sampling failed for this configuration (No finite path found).
#
# --- Scenario 129 (Size: 500, Density: 0.2, Neg: True) ---
#   BF Result | Cost: 523.00 | Time: 0.1688s | Path: [418, 438, 102, 116]
#   A* Result | Cost: 523.00 | Time: 0.2065s | Path: [418, 438, 102, 116]
#
# --- Scenario 130 (Size: 500, Density: 0.2, Neg: True) ---
#   Path sampling failed for this configuration (No finite path found).
#
# --- Scenario 131 (Size: 500, Density: 0.2, Neg: True) ---
#   Path sampling failed for this configuration (No finite path found).
#
# --- Scenario 132 (Size: 500, Density: 0.2, Neg: True) ---
#   Path sampling failed for this configuration (No finite path found).
#
# --- Scenario 133 (Size: 500, Density: 0.5, Neg: True) ---
#   BF Result | Cost: 665.00 | Time: 0.4081s | Path: [72, 340, 2]
#   A* Result | Cost: 665.00 | Time: 0.2257s | Path: [72, 340, 2]
#
# --- Scenario 134 (Size: 500, Density: 0.5, Neg: True) ---
#   Path sampling failed for this configuration (No finite path found).
#
# --- Scenario 135 (Size: 500, Density: 0.5, Neg: True) ---
#   Path sampling failed for this configuration (No finite path found).
#
# --- Scenario 136 (Size: 500, Density: 0.5, Neg: True) ---
#   Path sampling failed for this configuration (No finite path found).
#
# --- Scenario 137 (Size: 500, Density: 0.8, Neg: True) ---
#   BF Result | Cost: 730.00 | Time: 0.6272s | Path: [400, 32, 484, 366]
#   A* Result | Cost: 730.00 | Time: 0.2403s | Path: [400, 32, 484, 366]
#
# --- Scenario 138 (Size: 500, Density: 0.8, Neg: True) ---
#   Path sampling failed for this configuration (No finite path found).
#
# --- Scenario 139 (Size: 500, Density: 0.8, Neg: True) ---
#   Path sampling failed for this configuration (No finite path found).
#
# --- Scenario 140 (Size: 500, Density: 0.8, Neg: True) ---
#   Path sampling failed for this configuration (No finite path found).
#
# --- Scenario 141 (Size: 500, Density: 1.0, Neg: True) ---
#   BF Result | Cost: 606.00 | Time: 0.9195s | Path: [89, 235, 303]
#   A* Result | Cost: 606.00 | Time: 0.2510s | Path: [89, 235, 303]
#
# --- Scenario 142 (Size: 500, Density: 1.0, Neg: True) ---
#   Path sampling failed for this configuration (No finite path found).
#
# --- Scenario 143 (Size: 500, Density: 1.0, Neg: True) ---
#   Path sampling failed for this configuration (No finite path found).
#
# --- Scenario 144 (Size: 500, Density: 1.0, Neg: True) ---
#   Path sampling failed for this configuration (No finite path found).
#
# --- Scenario 145 (Size: 1000, Density: 0.2, Neg: True) ---
#   BF Result | Cost: 462.00 | Time: 0.7273s | Path: [423, 286, 265, 565]
#   A* Result | Cost: 462.00 | Time: 0.8572s | Path: [423, 286, 265, 565]
#
# --- Scenario 146 (Size: 1000, Density: 0.2, Neg: True) ---
#   Path sampling failed for this configuration (No finite path found).
#
# --- Scenario 147 (Size: 1000, Density: 0.2, Neg: True) ---
#   Path sampling failed for this configuration (No finite path found).
#
# --- Scenario 148 (Size: 1000, Density: 0.2, Neg: True) ---
#   Path sampling failed for this configuration (No finite path found).
#
# --- Scenario 149 (Size: 1000, Density: 0.5, Neg: True) ---
#   BF Result | Cost: 431.00 | Time: 1.7165s | Path: [209, 203, 324]
#   A* Result | Cost: 431.00 | Time: 0.8771s | Path: [209, 203, 324]
#
# --- Scenario 150 (Size: 1000, Density: 0.5, Neg: True) ---
#   Path sampling failed for this configuration (No finite path found).
#
# --- Scenario 151 (Size: 1000, Density: 0.5, Neg: True) ---
#   Path sampling failed for this configuration (No finite path found).
#
# --- Scenario 152 (Size: 1000, Density: 0.5, Neg: True) ---
#   Path sampling failed for this configuration (No finite path found).
#
# --- Scenario 153 (Size: 1000, Density: 0.8, Neg: True) ---
#   BF Result | Cost: 465.00 | Time: 3.1258s | Path: [558, 673]
#   A* Result | Cost: 465.00 | Time: 1.0842s | Path: [558, 673]
#
# --- Scenario 154 (Size: 1000, Density: 0.8, Neg: True) ---
#   Path sampling failed for this configuration (No finite path found).
#
# --- Scenario 155 (Size: 1000, Density: 0.8, Neg: True) ---
#   Path sampling failed for this configuration (No finite path found).
#
# --- Scenario 156 (Size: 1000, Density: 0.8, Neg: True) ---
#   Path sampling failed for this configuration (No finite path found).
#
# --- Scenario 157 (Size: 1000, Density: 1.0, Neg: True) ---
#   BF Result | Cost: 382.00 | Time: 4.0833s | Path: [741, 190, 970, 323]
#   A* Result | Cost: 382.00 | Time: 1.5739s | Path: [741, 190, 970, 323]
#
# --- Scenario 158 (Size: 1000, Density: 1.0, Neg: True) ---
#   Path sampling failed for this configuration (No finite path found).
#
# --- Scenario 159 (Size: 1000, Density: 1.0, Neg: True) ---
#   Path sampling failed for this configuration (No finite path found).
#
# --- Scenario 160 (Size: 1000, Density: 1.0, Neg: True) ---
#   Path sampling failed for this configuration (No finite path found).
#
# ======================================================================================================================================================
# Final Summary: Bellman-Ford (BF) vs. A* (One Sample Per Case)
# ======================================================================================================================================================
# |   size |   density |   noise_level | negative_values   |   Start |   Goal |   BF Cost |   A* Cost |   BF Time (s) |   A* Time (s) | BF Path                 | A* Path                 |
# |-------:|----------:|--------------:|:------------------|--------:|-------:|----------:|----------:|--------------:|--------------:|:------------------------|:------------------------|
# |     10 |      0.20 |          0.00 | False             |       5 |      6 |    492.00 |    492.00 |          0.00 |          0.00 | [5, 6]                  | [5, 6]                  |
# |     10 |      0.20 |          0.00 | True              |       6 |      9 |    794.00 |    794.00 |          0.00 |          0.00 | [6, 2, 9]               | [6, 2, 9]               |
# |     10 |      0.20 |          0.10 | False             |       9 |      7 |   1519.00 |   1519.00 |          0.00 |          0.00 | [9, 8, 6, 7]            | [9, 8, 6, 7]            |
# |     10 |      0.20 |          0.10 | True              |       8 |      0 |    837.00 |    837.00 |          0.00 |          0.00 | [8, 4, 0]               | [8, 4, 0]               |
# |     10 |      0.20 |          0.50 | False             |       2 |      8 |   2210.00 |   2210.00 |          0.00 |          0.00 | [2, 6, 1, 8]            | [2, 6, 1, 8]            |
# |     10 |      0.20 |          0.80 | False             |       3 |      8 |   1770.00 |   1770.00 |          0.00 |          0.00 | [3, 5, 6, 8]            | [3, 5, 6, 8]            |
# |     10 |      0.20 |          0.80 | True              |       8 |      7 |    949.00 |    949.00 |          0.00 |          0.00 | [8, 5, 0, 7]            | [8, 5, 0, 7]            |
# |     10 |      0.50 |          0.00 | False             |       5 |      0 |    886.00 |    886.00 |          0.00 |          0.00 | [5, 8, 0]               | [5, 8, 0]               |
# |     10 |      0.50 |          0.00 | True              |       1 |      6 |    629.00 |    629.00 |          0.00 |          0.00 | [1, 6]                  | [1, 6]                  |
